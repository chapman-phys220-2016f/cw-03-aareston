# %%
import plot_ball1
import read_2columns
import fill_arrays_vectorized
import matplotlib.pylab as plt

# %% [markdown]
# # Classwork 3
# ## Preston Kamada and Aaron Grisez

# %% [markdown]
# ## Problem 1
#
# The goal of this module is to vectorize the action of applying a function to a list of arguments. We take an array of 41 equally spaced values from $x = -4$ to $x = 4$ and apply the function $h(x)$ to each one.
#
# $$ h(x) = \frac{1}{\sqrt{2\pi}}\,e^{\frac{-1}{2}x^{2}}$$

# %%
fill_arrays_vectorized.main()
# Out:
# -4.00000 0.00013
# -3.80000 0.00029
# -3.60000 0.00061
# -3.40000 0.00123
# -3.20000 0.00238
# -3.00000 0.00443
# -2.80000 0.00792
# -2.60000 0.01358
# -2.40000 0.02239
# -2.20000 0.03547
# -2.00000 0.05399
# -1.80000 0.07895
# -1.60000 0.11092
# -1.40000 0.14973
# -1.20000 0.19419
# -1.00000 0.24197
# -0.80000 0.28969
# -0.60000 0.33322
# -0.40000 0.36827
# -0.20000 0.39104
# 0.00000 0.39894
# 0.20000 0.39104
# 0.40000 0.36827
# 0.60000 0.33322
# 0.80000 0.28969
# 1.00000 0.24197
# 1.20000 0.19419
# 1.40000 0.14973
# 1.60000 0.11092
# 1.80000 0.07895
# 2.00000 0.05399
# 2.20000 0.03547
# 2.40000 0.02239
# 2.60000 0.01358
# 2.80000 0.00792
# 3.00000 0.00443
# 3.20000 0.00238
# 3.40000 0.00123
# 3.60000 0.00061
# 3.80000 0.00029
# 4.00000 0.00013

# %% [markdown]
# ## Problem 2
#
# This plots the position of the ball in the y axis.
#
# $$ y(t) = y_0 + v_y t - \frac{g t^2}{2} $$

# %%
plot_ball1.plot_Gravity()

# %% [markdown]
# ## Problem 4
# Here, we take data in a 2 column .dat file and plot it using matplotlib. We also show the minimum, maximum, and mean values for y. (I had a bug in the second part that I couldn't find)

# %%
read_2columns.main()
